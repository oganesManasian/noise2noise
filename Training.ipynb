# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
import os

# %%
path = '/content/drive/My Drive/noise2noise'
os.chdir(path)

# %%
os.getcwd()
# Out:
# '/content/drive/My Drive/noise2noise'

# %%
# !ls
# Out:
# checkpoints	model.py	 simple_test_data  weights_gauss_noise.hdf5
# generated_data	noise_model.py	 test_model.py
# generator.py	plot_history.py  test_trained
# logs		__pycache__	 train.py

# %%
import tensorflow as tf
device_name = tf.test.gpu_device_name()
if device_name != '/device:GPU:0':
  raise SystemError('GPU device not found')
print('Found GPU at: {}'.format(device_name))
# Out:
# <p style="color: red;">
# The default version of TensorFlow in Colab will soon switch to TensorFlow 2.x.<br>
# We recommend you <a href="https://www.tensorflow.org/guide/migrate" target="_blank">upgrade</a> now
# or ensure your notebook will continue to use TensorFlow 1.x via the <code>%tensorflow_version 1.x</code> magic:
# <a href="https://colab.research.google.com/notebooks/tensorflow_version.ipynb" target="_blank">more info</a>.</p>
# Found GPU at: /device:GPU:0

# %% [markdown]
# Test on simple data with pretrained weights (Data needs to be noisy)

# %%
# !python3 test_model.py --model srresnet --weight_file weights_gauss_noise.hdf5 --nb_tests 10 \
--image_dir simple_test_data/ --output_dir simple_test_data_output

# %% [markdown]
# Train on our data

# %%
# !python3 train.py --model unet --weight checkpoints/weights.060-291.473.hdf5 --loss mse  --lr 0.001 --nb_epochs 60\
                  --image_dir generated_data/train --test_dir generated_data/test \
                  --image_size 256 --batch_size 4 --steps 400
# Out:
# Using TensorFlow backend.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:66: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:541: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4432: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4267: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# ...

# %%
# !python3 train.py --model srresnet --weight weights_gauss_noise.hdf5 --loss mse  --lr 0.001 --nb_epochs 5\
                  --image_dir generated_data/train --test_dir generated_data/test \
                  --image_size 256 --batch_size 4 --steps 2

# %% [markdown]
# Test on our data with pretrained weights

# %%
# !python3 test_model.py --model srresnet --weight_file weights_gauss_noise.hdf5 --nb_tests 10 \
--image_dir generated_data/test/ --output_dir test_pretrained

# %% [markdown]
# Test on our data with trained on our dataset weights (You need to update filename of weights)

# %%
# !python3 test_model.py --model unet --weight_file checkpoints/weights.060-291.473.hdf5 --nb_tests 20 \
--image_dir generated_data/test/ --output_dir test_trained
# Out:
# Using TensorFlow backend.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:66: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:541: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4432: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4267: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# ...

# %%
# !python3 test_model.py --model srresnet --weight_file checkpoints/weights.005-559.145-26.60323.hdf5 --nb_tests 10 \
--image_dir generated_data/test/ --output_dir test_our

# %%
# !python3 plot_history.py --input1 checkpoints
# Out:
# Started
# Drawed
# Saved
# Drawed
# Saved
